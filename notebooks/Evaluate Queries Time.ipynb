# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:8890/sparql/")
sparql.setQuery("""

        PREFIX RLWF: <https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#>
        
        SELECT (str(?title) as ?Title) (str(?counter) as ?Counter) (str(?desc) as ?Description)
        (str(?strdate) as ?Start_Date) (str(?enddate) as ?End_Date) FROM <http://localhost:8890/RLWF> WHERE  {
        
          # ?x RLWF:form_title ?title.
          # ?x RLWF:form_counter ?counter.
          # ?x RLWF:form_description ?desc.
          # ?x RLWF:form_startdate ?strdate. 
          # ?x RLWF:form_enddate ?enddate.
        FILTER(regex(?title, 'FREE RDF Webinar at the Avengers HQ')).
        }
        order by ?counter
             """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

print (results)
# Out:
# {'head': {'link': [], 'vars': ['Title', 'Counter', 'Description', 'Start_Date', 'End_Date']}, 'results': {'distinct': False, 'ordered': True, 'bindings': [{'Title': {'type': 'literal', 'value': 'FREE RDF Webinar at the Avengers HQ'}, 'Counter': {'type': 'literal', 'value': '1'}, 'Description': {'type': 'literal', 'value': 'Webinar will be hosted via Zoom with Scott Lang being the host. Max of 10 persons, so fill the form fast!'}, 'Start_Date': {'type': 'literal', 'value': '2021-06-05T10:24:00'}, 'End_Date': {'type': 'literal', 'value': '2021-06-30T10:24:00'}}]}}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:8890/sparql/")


sparql.setQuery("""

PREFIX RLWF: <https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT (strafter(str(?x), "#") AS ?form_instance) (strafter(str(?entity), "#") AS ?entity) (str(?counter) as ?qcounter) (str(?text) as ?text) (str(?q) as ?questiontype) (str(?wdt) as ?wdt)
FROM <http://localhost:8890/RLWF> WHERE {
# ?x RLWF:hasQuestion ?entity.
# ?x RLWF:form_title 'FREE RDF Webinar at the Avengers HQ'^^xsd:string.
# ?entity a ?type.
# ?type rdfs:label ?q.
# ?type rdfs:subClassOf* RLWF:Question.
# ?entity RLWF:text ?text.
# ?entity RLWF:question_counter ?counter.
OPTIONAL{?type RLWF:containsWDT ?wdt}.
}
ORDER BY asc(?entity)

""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
qcounter_array = []
text_array = []
qtypes_array = []
wdt_array = []
uids_array = []
form_instance = ""


values = []
for result in results["results"]["bindings"]:
    qcounter = result["qcounter"]["value"]
    text = result["text"]["value"]
    question_type = result["questiontype"]["value"]
    q_uid = result["entity"]["value"]
    wdt = result["wdt"]["value"]
    form_instance = result["form_instance"]["value"]
    qcounter_array.append(qcounter)
    text_array.append(text)
    qtypes_array.append(question_type)
    wdt_array.append(wdt)
    uids_array.append(q_uid)

print(results)
# Out:
# {'head': {'link': [], 'vars': ['form_instance', 'entity', 'qcounter', 'text', 'questiontype', 'wdt']}, 'results': {'distinct': False, 'ordered': True, 'bindings': [{'form_instance': {'type': 'literal', 'value': 'F01'}, 'entity': {'type': 'literal', 'value': 'F01Q01'}, 'qcounter': {'type': 'literal', 'value': '1'}, 'text': {'type': 'literal', 'value': 'What is your Name?'}, 'questiontype': {'type': 'literal', 'value': 'NameQuestion'}, 'wdt': {'type': 'literal', 'value': '0'}}, {'form_instance': {'type': 'literal', 'value': 'F01'}, 'entity': {'type': 'literal', 'value': 'F01Q02'}, 'qcounter': {'type': 'literal', 'value': '2'}, 'text': {'type': 'literal', 'value': 'What is your E-mail Address?'}, 'questiontype': {'type': 'literal', 'value': 'EmailQuestion'}, 'wdt': {'type': 'literal', 'value': '0'}}, {'form_instance': {'type': 'literal', 'value': 'F01'}, 'entity': {'type': 'literal', 'value': 'F01Q03'}, 'qcounter': {'type': 'literal', 'value': '3'}, 'text': {'type': 'literal', 'value': 'What is your Academic Degree?'}, 'questiontype': {'type': 'literal', 'value': 'AcademicInformationQuestion'}, 'wdt': {'type': 'literal', 'value': '1'}}, {'form_instance': {'type': 'literal', 'value': 'F01'}, 'entity': {'type': 'literal', 'value': 'F01Q04'}, 'qcounter': {'type': 'literal', 'value': '4'}, 'text': {'type': 'literal', 'value': 'How did you find out about this event?'}, 'questiontype': {'type': 'literal', 'value': 'CommunicationChannelQuestion'}, 'wdt': {'type': 'literal', 'value': '1'}}, {'form_instance': {'type': 'literal', 'value': 'F01'}, 'entity': {'type': 'literal', 'value': 'F01Q05'}, 'qcounter': {'type': 'literal', 'value': '5'}, 'text': {'type': 'literal', 'value': 'What do you apply RDF for?'}, 'questiontype': {'type': 'literal', 'value': 'Question'}, 'wdt': {'type': 'literal', 'value': '0'}}, {'form_instance': {'type': 'literal', 'value': 'F01'}, 'entity': {'type': 'literal', 'value': 'F01Q06'}, 'qcounter': {'type': 'literal', 'value': '6'}, 'text': {'type': 'literal', 'value': 'What country are you currently in?'}, 'questiontype': {'type': 'literal', 'value': 'CountryQuestion'}, 'wdt': {'type': 'literal', 'value': '1'}}]}}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:8890/sparql/")


sparql.setQuery("""

PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX RLWF: <https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#>

SELECT DISTINCT (strafter(str(?person), "#") AS ?person) (str(?name)) (str(?email) as ?email)FROM <http://localhost:8890/RLWF1>  WHERE {
  # ?person a prov:Person.
  # ?person RLWF:agent_name ?name.
  # ?person RLWF:agent_email ?email

}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
name_array = []
email_array = []



values = []
for result in results["results"]["bindings"]:
    x = result["person"]["value"]
    y = result["email"]["value"]

    qtypes_array.append(question_type)
    name_array.append(x)
    email_array.append(y)

print(results)
# Out:
# {'head': {'link': [], 'vars': ['person', 'callret-1', 'email']}, 'results': {'distinct': False, 'ordered': True, 'bindings': [{'person': {'type': 'literal', 'value': 'P01'}, 'callret-1': {'type': 'literal', 'value': 'Scott Lang'}, 'email': {'type': 'literal', 'value': 'scott.lang@av.com'}}, {'person': {'type': 'literal', 'value': 'P02'}, 'callret-1': {'type': 'literal', 'value': 'Carter Huang'}, 'email': {'type': 'literal', 'value': 'c.huang@gmail.com'}}, {'person': {'type': 'literal', 'value': 'P03'}, 'callret-1': {'type': 'literal', 'value': 'Julius Blaese'}, 'email': {'type': 'literal', 'value': 'julius@email.com'}}]}}

# %%
#list all agents

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:8890/sparql/")


sparql.setQuery("""

PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX RLWF: <https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#>

SELECT DISTINCT (strafter(str(?person), "#") AS ?person) (str(?name)) (str(?email) as ?email) FROM <http://localhost:8890/RLWF1>  WHERE {
  # ?person a prov:Person.
  # ?person RLWF:agent_name ?name.
  # ?person RLWF:agent_email ?email

}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
name_array = []
email_array = []



values = []
for result in results["results"]["bindings"]:
    x = result["person"]["value"]
    y = result["email"]["value"]

    qtypes_array.append(question_type)
    name_array.append(x)
    email_array.append(y)

print(results)
# Out:
# {'head': {'link': [], 'vars': ['person', 'callret-1', 'email']}, 'results': {'distinct': False, 'ordered': True, 'bindings': [{'person': {'type': 'literal', 'value': 'P01'}, 'callret-1': {'type': 'literal', 'value': 'Scott Lang'}, 'email': {'type': 'literal', 'value': 'scott.lang@av.com'}}, {'person': {'type': 'literal', 'value': 'P02'}, 'callret-1': {'type': 'literal', 'value': 'Carter Huang'}, 'email': {'type': 'literal', 'value': 'c.huang@gmail.com'}}, {'person': {'type': 'literal', 'value': 'P03'}, 'callret-1': {'type': 'literal', 'value': 'Julius Blaese'}, 'email': {'type': 'literal', 'value': 'julius@email.com'}}]}}

# %%
#list all activities

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:8890/sparql/")


sparql.setQuery("""

PREFIX RLWF: <https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#>

SELECT DISTINCT ?x ?y ?z ?a
FROM <http://localhost:8890/RLWF> 
WHERE {

# ?x a RLWF:CreateActivity.
# ?x prov:hadRole ?y.
# ?x prov:wasAssociatedWith ?z.
# ?x prov:atTime ?a.
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

activity = []
role = []
wasAssociatedWith = []
atTime = []



values = []
for result in results["results"]["bindings"]:
    x = result["x"]["value"]
    y = result["y"]["value"]
    z = result["z"]["value"]
    a = result["a"]["value"]
    
    activity.append(x)
    role.append(y)
    wasAssociatedWith.append(z)
    atTime.append(a)

print(results)
# Out:
# {'head': {'link': [], 'vars': ['x', 'y', 'z', 'a']}, 'results': {'distinct': False, 'ordered': True, 'bindings': [{'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#oKoQo8JM5vo8vxVfQog99w'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RUsrEiNcVVi64ZtySdadru'}, 'a': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'value': '2021-05-24T05:50:06'}}, {'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#Aud9fygTMdDdrnteTRdZHv'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#NV7vWY3UjrwddbFWjT2wDQ'}, 'a': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'value': '2021-05-24T05:50:06'}}, {'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#2vVU9MaBs9ivvD5XBy5rLn'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#X83ceeWZJWGJS99pEXEeGi'}, 'a': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'value': '2021-05-24T05:50:06'}}, {'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#eAWrJgTr2BkewaCX5TQsb3'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#hVJboHe9mdZwzBgCFK4pY6'}, 'a': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'value': '2021-05-24T05:50:06'}}, {'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#HPMnBpDuYA6rTvGhTiDPQg'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#C57XvqHVCRPLQR3jiUtocP'}, 'a': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'value': '2021-05-24T05:50:06'}}, {'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#2tV3ZxCDqwuPAQmHzJa2cE'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#JooKfA56henAC5HK3QwwwD'}, 'a': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'value': '2021-05-24T05:50:06'}}, {'x': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#JHYmvh3JWVY8VikRH5J6CM'}, 'y': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#RespondentRole'}, 'z': {'type': 'uri', 'value': 'https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#GVPTGaSSdjkXd2cy ...

# %%
#list all activities

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:8890/sparql/")


sparql.setQuery("""

PREFIX RLWF: <https://raw.githubusercontent.com/caiolopesdasilva/reliable_linked_web_forms/main/onto/RLWF.owl#>

SELECT DISTINCT
 (str(?hasText) as ?Question)
 (str(?text) as ?Answer)
 (strafter(str(?answerCluster), "#") AS ?answerCluster)
 (strafter(str(?entityURI), "#") AS ?entityURI)
 (str(?answer_uri) as ?Answer_uri)
 
FROM <http://localhost:8890/RLWF1> 
 

WHERE {
  # ?entityURI RLWF:hasAnswerTo ?question.
  # ?entityURI RLWF:answer_counter ?counter.
  # ?question RLWF:text ?hasText.
  # ?entityURI RLWF:individual_answer ?text.
  # ?answerCluster RLWF:hasIndividualAnswer ?entityURI.


OPTIONAL{?entityURI RLWF:answer_URI ?answer_uri}
}

order by asc(?counter)
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

activity = []
role = []
wasAssociatedWith = []
atTime = []



values = []
# for result in results["results"]["bindings"]:
#     x = result["x"]["value"]
#     y = result["y"]["value"]
#     z = result["z"]["value"]
#     a = result["a"]["value"]
    
#     activity.append(x)
#     role.append(y)
#     wasAssociatedWith.append(z)
#     atTime.append(a)

print(results)
# Out:
# {'head': {'link': [], 'vars': ['Question', 'Answer', 'answerCluster', 'entityURI', 'Answer_uri']}, 'results': {'distinct': False, 'ordered': True, 'bindings': [{'Question': {'type': 'literal', 'value': 'What is your Name?'}, 'Answer': {'type': 'literal', 'value': 'Carter Huang'}, 'answerCluster': {'type': 'literal', 'value': 'F01A01'}, 'entityURI': {'type': 'literal', 'value': 'F01A01Q01'}}, {'Question': {'type': 'literal', 'value': 'What is your Name?'}, 'Answer': {'type': 'literal', 'value': 'Julius Blaese'}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q01'}}, {'Question': {'type': 'literal', 'value': 'What is your E-mail Address?'}, 'Answer': {'type': 'literal', 'value': 'carter.huang@email.com'}, 'answerCluster': {'type': 'literal', 'value': 'F01A01'}, 'entityURI': {'type': 'literal', 'value': 'F01A01Q02'}}, {'Question': {'type': 'literal', 'value': 'What is your E-mail Address?'}, 'Answer': {'type': 'literal', 'value': 'j.blaese@email.com'}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q02'}}, {'Question': {'type': 'literal', 'value': 'What is your Academic Degree?'}, 'Answer': {'type': 'literal', 'value': "Bachelor's Degree in Computer Science"}, 'answerCluster': {'type': 'literal', 'value': 'F01A01'}, 'entityURI': {'type': 'literal', 'value': 'F01A01Q03'}, 'Answer_uri': {'type': 'literal', 'value': 'https://www.wikidata.org/wiki/Q21198'}}, {'Question': {'type': 'literal', 'value': 'What is your Academic Degree?'}, 'Answer': {'type': 'literal', 'value': "Master's Degree in Information Sciences at the VU"}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q03'}, 'Answer_uri': {'type': 'literal', 'value': 'Q1065414'}}, {'Question': {'type': 'literal', 'value': 'What is your Academic Degree?'}, 'Answer': {'type': 'literal', 'value': "Master's Degree in Information Sciences at the VU"}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q03'}, 'Answer_uri': {'type': 'literal', 'value': 'Q16387'}}, {'Question': {'type': 'literal', 'value': 'What is your Academic Degree?'}, 'Answer': {'type': 'literal', 'value': "Master's Degree in Information Sciences at the VU"}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q03'}, 'Answer_uri': {'type': 'literal', 'value': 'Q183816'}}, {'Question': {'type': 'literal', 'value': 'How did you find out about this event?'}, 'Answer': {'type': 'literal', 'value': 'Linkedin'}, 'answerCluster': {'type': 'literal', 'value': 'F01A01'}, 'entityURI': {'type': 'literal', 'value': 'F01A01Q04'}, 'Answer_uri': {'type': 'literal', 'value': 'Q213660'}}, {'Question': {'type': 'literal', 'value': 'How did you find out about this event?'}, 'Answer': {'type': 'literal', 'value': 'E-mail invitation'}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q04'}, 'Answer_uri': {'type': 'literal', 'value': 'Q9158'}}, {'Question': {'type': 'literal', 'value': 'What do you apply RDF for?'}, 'Answer': {'type': 'literal', 'value': 'Bachelor thesis'}, 'answerCluster': {'type': 'literal', 'value': 'F01A01'}, 'entityURI': {'type': 'literal', 'value': 'F01A01Q05'}, 'Answer_uri': {'type': 'literal', 'value': 'Q798134'}}, {'Question': {'type': 'literal', 'value': 'What do you apply RDF for?'}, 'Answer': {'type': 'literal', 'value': 'Just curious.'}, 'answerCluster': {'type': 'literal', 'value': 'F01A02'}, 'entityURI': {'type': 'literal', 'value': 'F01A02Q05'}}, {'Question': {'type': 'literal', 'value': 'What country are you currently in?'}, 'Answer': {'type': 'literal', 'value': 'Netherlands'}, 'answerCluster': {'type': 'literal', 'value': 'F01A01'}, 'entityURI': {'type': 'literal', 'value': 'F01A01Q06'}, 'Answer_uri': {'type': 'literal', 'value': 'Q55'}}, {'Question': {'type': 'litera ...
